# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

election = pd.read_csv("../dataset/election.csv")
election.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   district     58 non-null     object
#  1   Coderre      58 non-null     int64
#  2   Bergeron     58 non-null     int64
#  3   Joly         58 non-null     int64
#  4   total        58 non-null     int64
#  5   winner       58 non-null     object
#  6   result       58 non-null     object
#  7   district_id  58 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 3.8+ KB

# %%
election.loc[:,["Coderre","Bergeron","Joly"]].sum().plot(kind="bar")
# Out:
# <Axes: >

# %%
sns.barplot(election[["Coderre","Bergeron","Joly"]].sum())
# Out:
# <Axes: >

# %%
total_voters=election.groupby("district")["total"].sum().to_frame()
plt.figure(figsize=(10,12))
sns.barplot(election,y="district",x="total")
# Out:
# <Axes: xlabel='total', ylabel='district'>

# %%
compare = election.iloc[:4].set_index("district").loc[:,["Coderre","Bergeron","Joly"]]
compare.plot(kind="barh")
# Out:
# <Axes: ylabel='district'>

# %%
first_four = election.sort_values(ascending=False,by="total").iloc[:4]

df_lungo = pd.melt(first_four,id="")["Coderre","Bergeron","Joly"]

# %%
coderre= election.sort_values(ascending=False,by="Coderre").head(4)
bergeron= election.sort_values(ascending=False,by="Bergeron").head(4)
joly= election.sort_values(ascending=False,by="Joly").head(4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 5
#       2 bergeron= election.sort_values(ascending=False,by="Bergeron").head(4)
#       3 joly= election.sort_values(ascending=False,by="Joly").head(4)
# ----> 5 election.loc[[coderre,bergeron,joly]]
#
# File c:\Python312\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Python312\Lib\site-packages\pandas\core\indexing.py:1420, in _LocIndexer._getitem_axis(self, key, axis)
#    1417     if hasattr(key, "ndim") and key.ndim > 1:
#    1418         raise ValueError("Cannot index with multidimensional key")
# ...
