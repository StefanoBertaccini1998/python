# %%
import dotenv as dot
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import os
from sqlalchemy import create_engine

dot.load_dotenv("../.env")
username = os.getenv("username2")
password = os.getenv("password")
host = os.getenv("host")
dbname = "Titanic"

conn_str = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"

db_engine = create_engine(conn_str)
print(conn_str)
titanic = pd.read_sql("SELECT * FROM titanic",db_engine)
pd.read_sql("SHOW TABLES ",db_engine)

db_engine.dispose()
# Out:
# mysql+pymysql://studente_dapt:Ep1c0d3!!D4t4**4n4lys1s@epicode-data-pt-mysql.cvetyjye2qbl.eu-central-1.rds.amazonaws.com/Titanic

# %%
titanic.describe()
# Out:
#        PassengerId       PClass          Age        SibSp        Parch  \
# count  1309.000000  1309.000000  1309.000000  1309.000000  1309.000000
# mean    655.000000     2.294882    23.877517     0.498854     0.385027
# std     378.020061     0.837836    17.590845     1.041658     0.865560
# min       1.000000     1.000000     0.000000     0.000000     0.000000
# 25%     328.000000     2.000000     7.000000     0.000000     0.000000
# 50%     655.000000     3.000000    24.000000     0.000000     0.000000
# 75%     982.000000     3.000000    35.000000     1.000000     0.000000
# max    1309.000000     3.000000    80.000000     8.000000     9.000000
#
#               Fare     Survived
# count  1309.000000  1309.000000
# mean     33.270825     0.372804
# std      51.747086     0.483735
# min       0.000000     0.000000
# 25%       7.900000     0.000000
# 50%      14.450000     0.000000
# 75%      31.280000     1.000000
# max     512.330000     1.000000

# %%
sns.countplot(data=titanic,x="PClass")
plt.title("Titanic Passengers")
plt.xlabel("Embarc class")
plt.ylabel("Passengers")
# Out:
# Text(0, 0.5, 'Passengers')

# %%
alive = titanic[titanic["Survived"]==1]
sns.countplot(data=alive,x="PClass")
plt.title("Titanic Passengers")
plt.xlabel("Embarc class")
plt.ylabel("Passengers alive")
# Out:
# Text(0, 0.5, 'Passengers alive')

# %%
titanic.Fare.plot(kind="hist",grid=True)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.histplot(data=titanic,x="Fare")
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
sns.boxplot(data=titanic,x="PClass",y="Age")
# Out:
# <Axes: xlabel='PClass', ylabel='Age'>

# %%
sns.boxplot(data=titanic, x='PClass', y='Age', order=['1','2','3'])
# Out:
# <Axes: xlabel='PClass', ylabel='Age'>

# %%
sns.violinplot(data=titanic,x="PClass",y="Age")
# Out:
# <Axes: xlabel='PClass', ylabel='Age'>

# %%
sns.boxplot(data=titanic,y="Fare",x="Survived")
# Out:
# <Axes: xlabel='Survived', ylabel='Fare'>

# %%
alive = titanic[titanic["PClass"]==1]
sns.countplot(data=alive,x="Fare")
plt.title("Titanic Passengers")
plt.xlabel("Embarc class")
plt.ylabel("Passengers alive")
# Out:
# Text(0, 0.5, 'Passengers alive')

# %%
alive = titanic[titanic["PClass"]==3]
alive = alive[titanic["Survived"]==1]
alive["Fare"].describe()
# Out:
# C:\Users\elber\AppData\Local\Temp\ipykernel_4788\1949101901.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   alive = alive[titanic["Survived"]==1]
# count    175.000000
# mean      13.028400
# std        9.309531
# min        0.000000
# 25%        7.750000
# 50%        8.110000
# 75%       15.740000
# max       56.500000
# Name: Fare, dtype: float64

# %%
alive = titanic[titanic["PClass"]==1]
alive = alive[titanic["Survived"]==1]
alive["Fare"].describe()
# Out:
# C:\Users\elber\AppData\Local\Temp\ipykernel_4788\809830479.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   alive = alive[titanic["Survived"]==1]
# count    194.00000
# mean     100.27433
# std       88.48238
# min       25.70000
# 25%       51.57500
# 50%       77.34500
# 75%      120.00000
# max      512.33000
# Name: Fare, dtype: float64

# %%
price_corr = titanic.loc[:,["Fare", "PClass"]]
price_corr = titanic[["Fare", "PClass"]]
price_corr.corr()
# Out:
#             Fare    PClass
# Fare    1.000000 -0.558795
# PClass -0.558795  1.000000
